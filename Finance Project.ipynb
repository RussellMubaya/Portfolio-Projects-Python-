# %% [markdown]
# # Finance Data Project
#
# I focussed on bank stocks and see how they progressed throughout the [financial crisis](https://en.wikipedia.org/wiki/Financial_crisis_of_2007%E2%80%9308) all the way to early 2016.

# %% [markdown]
# ## Get the Data
#
# First we need to start with the proper imports, which we've already laid out for you here.
#
# I installed the pandas-datareader from a github page.(https://github.com/pydata/pandas-datareader) Pandas datareader allows me to [read stock information directly from the internet](http://pandas.pydata.org/pandas-docs/stable/remote_data.html). The I used these links for install guidance (**pip install pandas-datareader**),

# %%
from pandas_datareader import data, wb
import pandas as pd
import numpy as np
import datetime
# %matplotlib inline

# %% [markdown]
# ## Data
#
# Using pandas datareaders, i got the stock information for the following banks:
# *  Bank of America
# * CitiGroup
# * Goldman Sachs
# * JPMorgan Chase
# * Morgan Stanley
# * Wells Fargo
#
# ** Then I figured out how to get the stock data from Jan 1st 2006 to Jan 1st 2016 for each of these banks. Set each bank to be a separate dataframe, with the variable name for that bank being its ticker symbol. I found out this involved a few steps:**
# 1. Use datetime to set start and end datetime objects.
# 2. Figure out the ticker symbol for each bank.
# 2. Figure out how to use datareader to grab info on the stock.
#
# ** [this documentation page](https://pandas-datareader.readthedocs.io/en/latest/remote_data.html) was used for hints and instructions (it was just be a matter of replacing certain values. Tried to use google finance as a source, for example:**
#
#     # Bank of America
#     BAC = data.DataReader("BAC", 'google', start, end)
#
# ###  "google" DID NOT ALWAYS WORK, So i used the lastest working API available like 'stooq'
# ------------

# %%
# Stock data from stooq site, google finance data is retrievabale
start = datetime.datetime(2006,1,1)
end = datetime.datetime(2016,1,1)
BAC = data.DataReader('BAC', 'stooq', start, end)
BAC
# Out:
#                Open     High      Low    Close        Volume
# Date
# 2015-12-31  14.8678  14.9192  14.7088  14.7088  5.385572e+07
# 2015-12-30  15.0347  15.0683  14.8936  14.9034  4.007305e+07
# 2015-12-29  15.0773  15.1662  15.0002  15.1009  5.220538e+07
# 2015-12-28  15.0505  15.0595  14.8402  14.9716  4.775516e+07
# 2015-12-24  15.1375  15.1918  15.0505  15.0940  3.360696e+07
# ...             ...      ...      ...      ...           ...
# 2006-01-09  39.5481  39.7605  39.2439  39.4474  1.845131e+07
# 2006-01-06  39.6153  39.7082  39.2370  39.4208  1.487831e+07
# 2006-01-05  39.4296  39.6430  39.2113  39.4820  1.751074e+07
# 2006-01-04  39.7862  39.9916  39.3189  39.4296  2.097767e+07
# 2006-01-03  39.7180  39.9344  39.0661  39.8533  1.925141e+07
#
# [2517 rows x 5 columns]

# %%
start = datetime.datetime(2006,1,1)
end = datetime.datetime(2016,1,1)
C = data.DataReader('C', 'stooq', start, end)
C
# Out:
#                 Open      High       Low     Close        Volume
# Date
# 2015-12-31   43.8793   44.1477   43.6090   43.6090  1.337573e+07
# 2015-12-30   44.5299   44.6131   44.0328   44.0734  1.039755e+07
# 2015-12-29   44.4606   44.8488   44.4428   44.6477  1.204887e+07
# 2015-12-28   44.3002   44.3002   43.7872   44.1397  1.039563e+07
# 2015-12-24   44.2269   44.6388   44.2011   44.4170  5.543171e+06
# ...              ...       ...       ...       ...           ...
# 2006-01-09  406.8280  407.9970  404.3030  405.0660  2.007837e+06
# 2006-01-06  409.1850  409.3240  403.4810  406.9770  1.636869e+06
# 2006-01-05  405.4820  408.3340  405.1550  406.9770  1.356199e+06
# 2006-01-04  409.0370  411.0270  404.7190  404.9870  2.235056e+06
# 2006-01-03  410.1850  413.3440  402.7190  412.6110  1.836840e+06
#
# [2517 rows x 5 columns]

# %%
start = datetime.datetime(2006,1,1)
end = datetime.datetime(2016,1,1)
GS = data.DataReader('GS', 'stooq', start, end)
GS
# Out:
#                Open     High      Low    Close        Volume
# Date
# 2015-12-31  160.241  161.771  159.245  159.412  2.004923e+06
# 2015-12-30  162.116  162.322  160.814  160.972  1.712091e+06
# 2015-12-29  161.711  162.905  161.435  162.322  2.090293e+06
# 2015-12-28  160.764  160.892  159.087  160.646  1.948370e+06
# 2015-12-24  161.218  162.007  160.982  161.405  1.252273e+06
# ...             ...      ...      ...      ...           ...
# 2006-01-09  106.252  108.027  105.848  107.831  5.711751e+06
# 2006-01-06  105.265  106.883  105.265  106.549  5.223349e+06
# 2006-01-05  104.210  105.285  103.875  105.079  4.492009e+06
# 2006-01-04  105.295  106.617  104.546  105.117  5.878620e+06
# 2006-01-03  104.792  107.051  102.740  106.577  7.459316e+06
#
# [2517 rows x 5 columns]

# %%
start = datetime.datetime(2006,1,1)
end = datetime.datetime(2016,1,1)
JPM = data.DataReader('JPM', 'stooq', start, end)
JPM
# Out:
#                Open     High      Low    Close        Volume
# Date
# 2015-12-31  54.8667  55.3524  54.7071  54.7358  1.767721e+07
# 2015-12-30  55.5695  55.5764  55.0788  55.1967  8.673990e+06
# 2015-12-29  55.4039  55.7836  55.3207  55.5913  1.184786e+07
# 2015-12-28  54.9460  55.0788  54.4672  55.0243  7.974986e+06
# 2015-12-24  55.2235  55.4446  54.9737  55.2057  5.390582e+06
# ...             ...      ...      ...      ...           ...
# 2006-01-09
#
# Bank Ticker                                           ...       MS           \
# Stock Info      High      Low    Close        Volume  ...     Open     High
# Date                                                  ...
# 2006-01-03   413.344  402.719  412.611  1.836840e+06  ...  37.8570  38.7278
# 2006-01-04   411.027  404.719  404.987  2.235056e+06  ...  38.8704  39.2548
# 2006-01-05   408.334  405.155  406.977  1.356199e+06  ...  38.6386  38.7991
# ...

# %% [markdown]
# # EDA
#
# Here I explored the data a bit, as I tried to answer the following questions.
#
#
# ** What is the max Close price for each bank's stock throughout the time period?**

# %%
# 2 ways to solve this
for tick in tickers:
    print(tick, bank_stocks[tick]['Close'].max())
# Out:
# BAC 46.4714
# C 472.214
# GS 205.027
# JPM 57.6748
# MS 59.1303
# WFC 47.3958

# %%
# the other way using .xs
bank_stocks.xs(key='Close', axis=1,level='Stock Info').max()
# Out:
# Bank Ticker
# BAC     46.4714
# C      472.2140
# GS     205.0270
# JPM     57.6748
# MS      59.1303
# WFC     47.3958
# dtype: float64

# %% [markdown]
# ** Created a new empty DataFrame called returns. This dataframe will contain the returns for each bank's stock. returns are typically defined by:**
#
# $$r_t = \frac{p_t - p_{t-1}}{p_{t-1}} = \frac{p_t}{p_{t-1}} - 1$$

# %%
returns = pd.DataFrame()

# %% [markdown]
# ** Used pandas pct_change() method on the Close column to create a column representing this return value. Created a for loop that goes and for each Bank Stock Ticker creates this returns column and set's it as a column in the returns DataFrame.**

# %%
for tick in tickers:
    returns[tick + 'Return'] = bank_stocks[tick]['Close'].pct_change()
returns
# Out:
#             BACReturn   CReturn  GSReturn  JPMReturn  MSReturn  WFCReturn
# Date
# 2006-01-03        NaN       NaN       NaN        NaN       NaN        NaN
# 2006-01-04  -0.010631 -0.018477 -0.013699  -0.014308  0.000821  -0.011607
# 2006-01-05   0.001329  0.004914 -0.000362   0.003130  0.002717  -0.000998
# 2006-01-06  -0.001550  0.000000  0.013989   0.007064  0.001025   0.005702
# 2006-01-09   0.000675 -0.004696  0.012032   0.016240  0.010445   0.000000
# ...               ...       ...       ...        ...       ...        ...
# 2015-12-24  -0.004104  0.001452 -0.002503  -0.001916 -0.003611  -0.004024
# 2015-12-28  -0.008109 -0.006243 -0.004702  -0.003286 -0.009600  -0.002471
# 2015-12-29   0.008636  0.011509  0.010433   0.010305  0.011816   0.011087
# 2015-12-30  -0.013079 -0.012863 -0.008317  -0.007098 -0.009799  -0.007223
# 2015-12-31  -0.013057 -0.010537 -0.009691  -0.008350 -0.012995  -0.009633
#
# [2517 rows x 6 columns]

# %% [markdown]
# ** Created a pairplot using seaborn of the returns dataframe. What stock stands out to you? Can you figure out why?**

# %%
import seaborn as sns
sns.pairplot(returns)
sns.

# %% [markdown]
# ** Using this returns DataFrame, figured out on what dates each bank stock had the best and worst single day returns. **

# %%
returns.idxmin()
# Out:
# BACReturn   2009-01-20
# CReturn     2009-02-27
# GSReturn    2009-01-20
# JPMReturn   2009-01-20
# MSReturn    2008-10-09
# WFCReturn   2009-01-20
# dtype: datetime64[ns]

# %% [markdown]
# ** You should have noticed that Citigroup's largest drop and biggest gain were very close to one another, did anythign significant happen in that time frame? **

# %% [markdown]
# * See Solution for details

# %%
returns.idxmax()
# Out:
# BACReturn   2009-04-09
# CReturn     2008-11-24
# GSReturn    2008-11-24
# JPMReturn   2009-01-21
# MSReturn    2008-10-13
# WFCReturn   2008-07-16
# dtype: datetime64[ns]

# %%
returns.std()
# Out:
# BACReturn    0.036605
# CReturn      0.038615
# GSReturn     0.025371
# JPMReturn    0.027670
# MSReturn     0.037708
# WFCReturn    0.030221
# dtype: float64

# %%
returns.loc['2015-01-01':'2015-12-31'].std()
# Out:
# BACReturn    0.016149
# CReturn      0.015280
# GSReturn     0.014028
# JPMReturn    0.013964
# MSReturn     0.016006
# WFCReturn    0.012545
# dtype: float64

# %%
# Morgan Stanley has the lowest risk in 2015, and would be the safer option to go for all in all as an investor that year.
# This is indicated by the very low standard deviation it has compared to the rest. Bank of America would be the riskiest
# Out:
# BAC Return    0.016163
# C Return      0.015289
# GS Return     0.014046
# JPM Return    0.014017
# MS Return     0.016249
# WFC Return    0.012591
# dtype: float64

# %% [markdown]
# ** Created a distplot using seaborn of the 2015 returns for Morgan Stanley **

# %%
sns.distplot(returns.loc['2015-01-01':'2015-12-31']['MSReturn'], color='green', bins=50)
# Out:
# /Users/russellmubaya/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='MSReturn', ylabel='Density'>

# %% [markdown]
# ** Create a distplot using seaborn of the 2008 returns for CitiGroup **

# %%
sns.distplot(returns.loc['2008-01-01':'2008-12-31']['MSReturn'], color='green', bins=50)
# Out:
# /Users/russellmubaya/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='MSReturn', ylabel='Density'>

# %% [markdown]
# ____
# # More Visualization

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
# %matplotlib inline

# Optional Plotly Method Imports
import plotly
import cufflinks as cf
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.16.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ** Created a line plot showing Close price for each bank for the entire index of time. Tried using a for loop, or use [.xs](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.xs.html) to get a cross section of the data.**

# %%
# 2 ways to do this
for tick in tickers:
    bank_stocks[tick]['Close'].plot(label=tick, figsize=(12,4))
plt.legend()

# %%
#second way
bank_stocks.xs(key='Close', axis=1, level='Stock Info').plot(label=tick, figsize=(12,4))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# We can make our diagram a lot nice by making it interractive through plotly
bank_stocks.xs(key='Close', axis=1, level='Stock Info').iplot()
# Out:
# <div>                            <div id="7e0ef7fa-9606-4809-9198-71e57d65de49" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# ## Moving Averages
#
# Analyzed the moving averages for these stocks in the year 2008.
#
# ** Plotted the rolling 30 day average against the Close Price for Bank Of America's stock for the year 2008**

# %%
plt.figure(figsize(12,4))
BAC['Close'].loc['2008=01-01':'2009-01-01'].rolling(window=30).mean().plot(label='30 Day Mov Avg')
BAC['Close'].loc['2008=01-01':'2009-01-01'].plot(label='BAC CLOSE')
plt.legend()

# %% [markdown]
# ** Created a heatmap of the correlation between the stocks Close Price.**

# %%
corr = bank_stocks.xs(key='Close',axis=1,level='Stock Info').corr()
sns.heatmap(corr, annot=True)
# Out:
# <AxesSubplot:xlabel='Bank Ticker', ylabel='Bank Ticker'>

# %% [markdown]
# ** Used seaborn's clustermap to cluster the correlations together:**

# %%
sns.clustermap(corr, annot=True)

# %% [markdown]
# # Use of Cufflinks
#
# In this second part of the project I relied on the cufflinks library to create some Technical Analysis plots. This part of the project was experimental.

# %% [markdown]
# ** Used .iplot(kind='candle) to create a candle plot of Bank of America's stock from Jan 1st 2015 to Jan 1st 2016.**

# %%
bac15 = BAC[['Open','High','Low','Close']].loc['2015-01-01':'2016-01-01']
bac15.iplot(filename ='candle')
# Out:
# <div>                            <div id="97eed54d-da8f-4af1-8754-84b76f033f32" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# ** Used .ta_plot(study='sma') to create a Simple Moving Averages plot of Morgan Stanley for the year 2015.**

# %%
MS['Close'].loc['2015-01-01':'2016-01-01'].ta_plot(study='sma', periods=[13,21,55])
# Out:
# <div>                            <div id="f3574108-2012-4ed9-8977-1bb05bdf3148" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# **Used .ta_plot(study='boll') to create a Bollinger Band Plot for Bank of America for the year 2015.**

# %%
MS['Close'].loc['2016-01-01':'2017-01-01'].ta_plot(study='boll', periods=[13,21,55])
# Out:
# <div>                            <div id="f2d93442-7f19-4e29-90bb-3eb3e2a1f796" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...
